# %% [markdown]
# Heading

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv(r'd:\AI\SVM\AIProject\Data\CSV\silver_price_forecast_jan_mar_2026.csv')

# Display the first few rows
print(df.head())

# Display info about the dataframe
print(df.info())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 # Read the CSV file
#       4 df = pd.read_csv(r'd:\AI\SVM\AIProject\Data\CSV\silver_price_forecast_jan_mar_2026.csv')
#
# ModuleNotFoundError: No module named 'pandas'
